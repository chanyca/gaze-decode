# %% [markdown]
# Find microsaccades using EngbertMicrosaccadeToolbox
# Mostly following their demo

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
import sys
import os
sys.path.append(os.path.abspath('EngbertMicrosaccadeToolbox'))
from EngbertMicrosaccadeToolbox import microsac_detection
# import microsac_detection

# %%
d = pd.read_csv('eyelink_csv/SV009_sample_trialno_phase.csv')
d.head()
# Get rows for trial_no=1, phase='s', LX, LY not empty
# d = d[(d['trial_no']==400) & (d['phase']=='s') & (d['LX'].notnull()) & (d['LY'].notnull())]
d = d[(d['phase']=='s') & (d['LX'].notnull()) & (d['LY'].notnull())]
# print(d.head())
# print(d.trial_no.unique())

# plt.plot(d.LX, label='LX')
# plt.plot(d.LY, label='LY')
# plt.legend()

# Set parameters
SAMPLING = 250 # sampling rate, hz
MINDUR = 1 # minimal saccade duration, originally 3
VFAC = 5 # relative velocity threshold, originally 5

microsac_dict = {}
for trial_no in d.trial_no.unique():
    trial_d = d[d['trial_no']==trial_no]
    print(trial_d.head())
    left_eye = np.vstack([np.asarray(trial_d.LX), np.asarray(trial_d.LY)]).T
    if left_eye.size > 0:
        ms_l, rad_l = microsac_detection.microsacc(left_eye, vfac=VFAC, mindur=MINDUR, sampling=SAMPLING)
        microsac_dict[trial_no] = ms_l
    else:
        print(f"Skipping trial_no {trial_no} due to empty left_eye array")

microsac_dict
# Out:
#      tSample      LX      LY  LPupil  RX  RY  RPupil  trial_no phase
# 825  1464909  1934.3  1097.3   731.0 NaN NaN     NaN         1     s
# 826  1464913  1934.5  1096.8   731.0 NaN NaN     NaN         1     s
# 827  1464917  1934.2  1096.6   732.0 NaN NaN     NaN         1     s
# 828  1464921  1933.7  1096.9   733.0 NaN NaN     NaN         1     s
# 829  1464925  1933.0  1097.6   733.0 NaN NaN     NaN         1     s
# [[ 0.00000000e+00  0.00000000e+00]
#  [-1.25000000e+01 -8.75000000e+01]
#  [-8.75000000e+01  1.66666667e+01]
#  [-1.20833333e+02  8.33333333e+01]
#  [-9.58333333e+01  6.25000000e+01]
#  [-3.33333333e+01 -4.16666667e+01]
#  [ 2.91666667e+01 -1.58333333e+02]
#  [ 4.16666667e+01 -2.29166667e+02]
#  [ 1.25000000e+01 -2.41666667e+02]
#  [-3.33333333e+01 -2.25000000e+02]
#  [-4.58333333e+01 -2.04166667e+02]
#  [-1.66666667e+01 -1.66666667e+02]
#  [ 1.25000000e+01 -1.00000000e+02]
#  [ 1.66666667e+01 -9.47390314e-12]
#  [-8.33333333e+00  5.83333333e+01]
#  [-3.33333333e+01  2.50000000e+01]
#  [-2.91666667e+01 -7.50000000e+01]
#  [-4.16666667e+00 -2.04166667e+02]
#  [ 2.91666667e+01 -3.04166667e+02]
#  [ 5.83333333e+01 -3.37500000e+02]
#  [ 7.91666667e+01 -2.79166667e+02]
#  [ 7.91666667e+01 -1.45833333e+02]
#  [ 4.16666667e+01 -4.58333333e+01]
#  [-8.33333333e+00 -4.58333333e+01]
#  [-5.41666667e+01 -1.16666667e+02]
#  [-9.58333333e+01 -1.58333333e+02]
#  [-1.37500000e+02 -1.16666667e+02]
#  [-1.70833333e+02 -4.16666667e+01]
#  [-1.54166667e+02  3.33333333e+01]
#  [-9.16666667e+01  1.00000000e+02]
#  [-1.66666667e+01  1.66666667e+02]
#  [ 2.91666667e+01  2.08333333e+02]
#  [ 3.75000000e+01  1.87500000e+02]
#  [ 3.33333333e+01  1.20833333e+02]
#  [ 2.50000000e+01  5.00000000e+01]
#  [ 1.66666667e+01  4.16666667e+00]
#  [ 8.33333333e+00 -2.50000000e+01]
#  [ 1.66666667e+01 -5.41666667e+01]
#  [ 2.50000000e+01 -6.66666667e+01]
#  [ 2.91666667e+01 -5.00000000e+01]
#  [ 2.08333333e+01 -8.33333333e+00]
#  [ 4.16666667e+00  3.75000000e+01]
#  [-1.66666667e+01  4.16666667e+01]
#  [-5.41666667e+01 -8.33333333e+00]
#  [-8.33333333e+01 -8.75000000e+01]
#  [-8.33333333e+01 -1.50000000e+02]
#  [-5.41666667e+01 -1.83333333e+02]
#  [-6.66666667e+01 -1.79166667e+02]
#  [-1.45833333e+02 -1.08333333e+02]
#  [-2.41666667e+02  1.25000000e+01]
#  [-2.62500000e+02  1.37500000e+02]
#  [-1.79166667e+02  1.91666667e+02]
#  [-5.83333333e+01  1.50000000e+02]
#  [ 4.16666667e+01  6.66666667e+01]
#  [ 9.16666667e+01  2.91666667e+01]
#  [ 1.16666667e+02  6.66666667e+01]
#  [ 1.25000000e+02  9.16666667e+01]
#  [ 1.16666667e+02  2.50000000e+01]
#  [ 8.75000000e+01 -1.04166667e+02]
#  [ 5.00000000e+01 -1.70833333e+02]
#  [ 2.08333333e+01 -1.20833333e+02]
#  [ 0.00000000e+00  2.50000000e+01]
#  [ 0.00000000e+00  0.00000000e+00]]
#       tSample      LX      LY  LPupil  RX  RY  RPupil  trial_no phase
# 5463  1483461  1935.9  1070.6   776.0 NaN NaN     NaN         2     s
# 5464  1483465  1936.0  1070.9   776.0 NaN NaN     NaN         2     s
# 5465  1483469  1936.3  1071.3   777.0 NaN NaN     NaN         2     s
# 5466  1483473  1936.7  1071.5   777.0 NaN NaN     NaN         2     s
# 5467  1483477  1937.1  1071.6   777.0 NaN NaN     NaN         2     s
# [[   0.            0.        ]
#  [  50.           87.5       ]
#  [  79.16666667   66.66666667]
#  [  95.83333333   37.5       ]
#  [  91.66666667    8.33333333]
#  [  79.16666667    0.        ]
#  [  62.5           4.16666667]
#  [  16.66666667   16.66666667]
#  [ -75.           33.33333333]
#  [-195.83333333   50.        ]
#  [-291.66666667   50.        ]
#  [-320.83333333   12.5       ]
#  [-287.5         -50.        ]
#  [-216.66666667 -112.5       ]
#  [-145.83333333 -133.33333333]
#  [-100.          -91.66666667]
#  [ -75.          -20.83333333]
#  [ -66.66666667   37.5       ]
#  [ -66.66666667   83.33333333]
#  [ -75.          158.33333333]
#  [ -75.          245.83333333]
#  [ -37.5         275.        ]
#  [  37.5         191.66666667]
#  [ 120.83333333   29.16666667]
#  [ 162.5        -104.16666667]
#  [ 145.83333333 -145.83333333]
#  [  87.5        -108.33333333]
#  [  58.33333333  -75.        ]
#  [  87.5         -87.5       ]
#  [ 120.83333333 -120.83333333]
#  [ 100.         -141.66666667]
#  [  16.66666667 -125.        ]
#  [ -37.5         -83.33333333]
#  [ -20.83333333  -20.83333333]
#  [  20.83333333   41.66666667]
#  [  25.           70.83333333]
#  [ -33.33333333   58.33333333]
#  [-112.5          20.83333333]
#  [-183.33333333  -20.83333333]
#  [-216.66666667  -41.66666667]
#  [-183.33333333  -20.83333333]
#  [ -75.           33.33333333]
#  [  58.33333333   87.5       ]
#  [ 145.83333333   91.66666667]
#  [ 158.33333333   58.33333333]
#  [ 108.33333333   33.33333333]
#  [  29.16666667   29.16666667]
#  [ -58.33333333   20.83333333]
#  [-129.16666667  -29.16666667]
#  [-166.66666667 -104.16666667]
#  [-170.83333333 -158.33333333]
#  [-175.         -158.33333333]
#  [-191.66666667  -95.83333333]
#  [-208.33333333    8.33333333]
#  [-216.66666667   95.83333333]
#  [-208.33333333  116.66666667]
#  [-200.           75.        ]
#  [-195.83333333   12.5       ]
#  [-200.          -25.        ]
#  [-200.          -33.33333333]
#  [-170.83333333  -25.        ]
#  [-112.5         -12.5       ]
#  [   0.            0.        ]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [2], in <cell line: 19>()
#      22 left_eye = np.vstack([np.asarray(trial_d.LX), np.asarray(trial_d.LY)]).T
#      23 if left_eye.size > 0:
# ---> 24     ms_l, rad_l = microsac_detection.microsacc(left_eye, vfac=VFAC, mindur=MINDUR, sampling=SAMPLING)
#      25     microsac_dict[trial_no] = ms_l
#      26 else:
#
# File c:\Users\Ailene\OneDrive - California Institute of Technology\Documents\GitHub\gaze-decode\EngbertMicrosaccadeToolbox\EngbertMicrosaccadeToolbox\microsac_detection.py:166, in microsacc(x, vfac, mindur, sampling)
#     163 end = int(s[1])
#     165 # Saccade peak velocity (vpeak)
# --> 166 vpeak = np.max(np.sqrt(v[start:end, 0]**2 + v[start:end, 1]**2))
#     167 # Saccade vector (dx,dy)
#     168 dx = x[end, 0] - x[start, 0]
#
# File <__array_function__ internals>:5, in amax(*args, **kwargs)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2754, in amax(a, axis, out, keepdims, initial, where)
#    2638 @array_function_dispatch(_amax_dispatcher)
#    2639 def amax(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    2640          where=np._NoValue):
#    2641     """
#    2642     Return the maximum of an array or maximum along an axis.
#    2643
#    (...)
#    2752     5
#    2753     """
# -> 2754     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    2755                           keepdims=keepdims, initial=initial, where=where)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# ValueError: zero-size array to reduction operation maximum which has no identity

# %%
# We're only analysing left eye here
# bino, monol, monor = microsac_detection.binsacc(ms_l, ms_l)
# Out:
# []
